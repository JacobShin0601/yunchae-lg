# %%
# %load_ext autoreload
# %autoreload 2

# %%
# %%writefile .env

# TAVILY_API_KEY = your_key
# JINA_API_KEY = your_key
# CHROME_INSTANCE_PATH = /Applications/Google Chrome.app/Contents/MacOS/Google Chrome
# BROWSER_HEADLESS=False

# %%
# import sys
# from src.workflow import run_agent_workflow

# %%
# ### 주요 핵심 개념
# - P-rate(Penetration Rate): 전체 차량 판매량 대비 전기차(POS(최종) 내에 EV + PHEV)의 비율을 나타낸 지표로 전기차의 보급률을 파악하는데에 핵심적인 지표

# %%
# user_query = """
# # 제목: ESS 관련 정보 정리

# ## 지침:
# # 당신은 북미의 데이터센터 ESS 관련 시장규모, 성장률, 트렌드 및 관련 규제와 법안 등의 Market Intelligence를 확보하고 있습니다.
# - 아래 법안 내용을 확인하고, 관련 정보 중, 최근 3개월의 자료를 조사해주세요.
# ------------------------------------------------------------------------------------------------
#     a. 데이터센터 확대에 따른 부하 대응 위하여 유틸리티의 ‘청정 에너지 계획’ 제출 의무화 법안 발의 (SB 2473 / HB 3779)
#         - 유틸리티의 州 전력청 향 최소 비용의 10년 구간 IRP 제출 의무화 (’25년 11월 1일 및 매 3년 주기 제출)
#         - 입법 배경 : ① 전력 요금 납부자의 비용 최소화 ② 화석 연료에서 재생 에너지 자원으로의 전환 기회 극대화
#                             ③ 발전원 포트폴리오 선택에 대한 투명성과 민주적 참여도 증대
#         - IRP 수립 시 주요 요소
#         ① 전력 수요-공급 적절성을 유지할 수 있는 자원 개발을 위한 다양한 시나리오를 검토해야 함
#         ② 예상 부하의 변경 사항(데이터센터의 대규모 전력 부하 증가, 운송/난방 분야 전기화 등)을 고려해야 함
#         ③ 재생 에너지 활용 비중 의무화
#             · ’26년 6월 1일까지 발전원의 25%, 연도별 3%p씩 증가하여 ’30년 40% 도달
#             · ’31년 ~ ’45년 : 계획된 재생에너지 발전원 부하의 100%를 공급하기 위해 ESS 활용 권장
#             · ’45년 1월 1일까지 모든 석탄 및 가스 발전 자원 폐기
# # 검색을 통해 정보를 수집하고 정리하여 레포트를 작성해주세요.
# # 레포트의 가장 앞에 Executive Summary를 작성해 주요한 insights를 정리해주세요.
# # 최종 레포트는 최종 결과물과 출처, 도표 등을 이용해 최종 결론을 도출해주세요.
# ------------------------------------------------------------------------------------------------

# ## Planner Agent
# - **반드시** **Researcher Agent**가 먼저 자료를 수집하고, 이후 Reporter Agent가 분석 및 레포트 작성을 하도록 순서를 구성해주세요.

# ## Coder Agent
# - Researcher Agent가 데이터를 수집하기 위한 키워드나 링크, 사이트 등을 미리 정의해주세요.

# ## Researcher Agent
# - 아래 사이트를 주로 탐색해주세요. 최근 3달 간의 자료 위주로 서술해주세요.
#     a. 업체/기관명 (Website 주소)
#         1. Energy Storage News (https://www.energy-storage.news/)
#         2. PV Megazine (http://www.pv-magazine.com)
#         3. Utility Dive (http://www.utilitydive.com/)
#         4. Electrek (https://electrek.co/)
#         5. Renew Economy (http://reneweconomy.com.au)
#         6. SNE 리서치 Daily News (https://www.sneresearch.com/kr/insight/news/)
#         7. PV Tech News (https://www.pv-tech.org/category/news/)
#         8. Cleantechnica (https://cleantechnica.com/)
#         9. 전기신문 (https://www.electimes.com/)
#         10. 파이낸셜뉴스 (https://www.fnnews.com/)
#         11. BNEF News (https://www.bnef.com/news)
#         12. SolarQuotes (https://www.solarquotes.com.au/blog/)
#         13. One Step off the Grid (https://onestepoffthegrid.com.au/)
#         14. ITP Renewable (https://batterytestcentre.com.au/reports/)
#         15. JEMA (https://www.jema-net.or.jp/Japanese/data/lib.html)
#         16. JPEA (https://www.jpea.gr.jp/)
#         17. SII (https://sii.or.jp/)
#         18. Tesla Powerwall (https://www.tesla.com/support/energy/powerwall/documents/documents)
#         19. BYD (https://www.bydbatterybox.com/downloads)
#         20. 에너지경제연구원 (https://www.keei.re.kr/main.nsf/index.html)
#         21. 배터리다이브 (https://batterydive.com/)
# - 내용을 정리할 때에는 반드시 출처를 명기해주세요.

# ## Reporter Agent
# - 파편적으로 모은 자료에서 insight를 도출하고 executive summary를 작성해주세요.
# - 내용을 MECE하게 요약하고 출처를 반드시 명기해주세요.
# - 레포트 가장 하단에 참고문헌 및 링크 등을 명기해주세요. (Researcher Agent가 모은 자료)
# """

# %%
# user_query="""
# # 제목: 북미(North America) 전기차 시장 분석

# ## 지침:
# # 당신은 LG Energy Solution의 전략 분석가이며 북미 시장의 전기차 배터리 시장에 대한 전략을 수립하고 있습니다.
# # 아래 자동차 생산량 데이터를 활용하여 분석방향에 따라 최종 레포트를 작성하세요. (**최종 레포트는 한국어로 작성**)
# # 레포트의 가장 앞에 Executive Summary를 작성해 주요한 insights를 정리해주세요.
# # 최종 레포트는 최종 결과물과 출처, 도표 등을 이용해 최종 결론을 도출해주세요.

# ### 분석방향
# ## 모든 분석은 가설을 수립하고(시나리오를 수립하고) 그에 따른 검증을 진행해주세요

# ## Researcher Agent
# - 아래 시나리오 플래닝에 필요한 추가 정보들을 검색하여 추가적으로 정보를 모아주세요.
#     a. 시나리오 플래닝: 트럼프 2기 정부 대중국 관세정책 시행 시 북미 전기차 시장에 미칠 영향
#     b. 분석결과는 2025년부터 2036년까지 P-rate 분석을 진행해주세요. (기존 vs. base/best/worst 시나리오)
#     c. 주안점: 공급망 측면에서의 변화 및 제약사항을 추론하고 향후 미칠 영향에 대해 플랜을 만들고 다양한 분석기법을 적용
# - 정보를 모을 때, 반드시 출처를 함께 명기해주세요.

# ## Coder Agent
# - 'artifacts/quarterly_aggregated_....csv'로는 새로운 분석을 할 필요가 없고 기존에 분석된 json 결과파일만 참조해 분석 및 해석에 집중해주세요.
# - 추가적으로 도표/차트 생성을 할 필요는 없습니다.

# ## Reporter Agent
# - 분석을 1. P-rate 분석 및 2. 자동차 생산량 및 거시경제 데이터 분석 및 3. 추가 분석 순으로 진행해주세요.
#     1. P-rate 분석은 '/artifacts' 폴더 내 'prate....json' 파일을 이해하고 분석하여 인사이트를 도출해주세요.
#         1.1. P-rate(penetration rate) 분석은 전체 차량 판매량 대비 전기차(POS(최종) 내에 EV + PHEV)의 비율을 나타낸 지표로, 전기차의 보급률을 파악하는데에 핵심적인 지표이며 Region(최종) 별로 참조합니다.
#         1.2. 이미 저장되어 있는 '/artifacts' 폴더 내 'prate....png' 도표를 레포트에 최대한 반영해주세요.
#     2. 자동차 생산량 및 거시경제 데이터 분석은 '/artifacts' 폴더 내 'quarterly_aggregated_....csv' 파일을 이해하고 분석하여 인사이트를 도출해주세요.
#         2.1. 이미 분석되어 있는 json 파일은 Cross-correlation, granger causality, variable importance 파일을 참조하여 결론을 도출합니다.
#         2.2. 거시경제 지표와 자동차 생산량의 관계는 'data/fred_dict.json'을 참조하여 설명해주세요.
#         2.3. 이미 저장되어 있는 '/artifacts' 폴더 내 'corr_....png', 'granger_....png', 'rf_test....png' 도표를 레포트에 최대한 반영해주세요.
#     3. 추가 분석은 1, 2번 분석에 필요한 추가 정보를 검색하여 추가적으로 정보를 모아주세요.
#         3.1. Researcher Agent가 수집한 데이터를 토대로 insight를 도출해주세요.
#         3.2. Researcher Agent가 수집한 데이터를 사용할 때에는 출처를 report에 명기해주세요.
#     4. 레포트 가장 하단에 참고문헌 및 링크 등을 명기해주세요. (Researcher Agent가 모은 자료)
# """

# %%
# user_query="""
# # 제목: 북미(North America) 전기차 시장 분석

# ## 지침:
# # 당신은 LG Energy Solution의 전략 분석가이며 북미 시장의 전기차 배터리 시장에 대한 전략을 수립하고 있습니다.
# # 아래 자동차 생산량 데이터를 활용하여 분석방향에 따라 최종 레포트를 작성하세요. (**최종 레포트는 한국어로 작성**)
# # 레포트의 가장 앞에 Executive Summary를 작성해 주요한 insights를 정리해주세요.
# # 최종 레포트는 최종 결과물과 출처, 도표 등을 이용해 최종 결론을 도출해주세요.

# ### 분석방향
# ## 모든 분석은 가설을 수립하고(시나리오를 수립하고) 그에 따른 검증을 진행해주세요

# ## Researcher Agent
# - 필요하다면 검색전략 작성(json 및 markdown)을 위해 Coder Agent를 활용해주세요.
# - 아래 시나리오 플래닝에 필요한 추가 정보들을 검색하여 추가적으로 정보를 모아주세요.
#     a. 시나리오 플래닝: 트럼프 2기 정부 대중국 관세정책 시행 시 북미 전기차 시장에 미칠 영향
#     b. 분석결과는 2025년부터 2036년까지 P-rate 분석을 위한 자료 (기존 vs. base/best/worst 시나리오)
# - 정보를 모을 때, 반드시 출처를 함께 명기해 주세요.
# - 최근 3달 간의 자료를 중심으로 분석해주세요.

# ## Coder Agent
# - 'artifacts/quarterly_aggregated_....csv'로는 새로운 분석을 할 필요가 없고 기존에 분석된 json 결과파일만 참조해 분석 및 해석에 집중해주세요.
# - 추가적으로 도표/차트 생성을 할 필요는 없습니다.

# ## Reporter Agent
# - 분석을 1. P-rate 분석 및 2. 자동차 생산량 및 거시경제 데이터 분석 및 3. 추가 분석 순으로 진행해주세요.
#     1. P-rate 분석은 '/artifacts' 폴더 내 'prate....json' 파일을 이해하고 분석하여 인사이트를 도출해주세요.
#         1.1. P-rate(penetration rate) 분석은 전체 차량 판매량 대비 전기차(POS(최종) 내에 EV + PHEV)의 비율을 나타낸 지표로, 전기차의 보급률을 파악하는데에 핵심적인 지표이며 Region(최종) 별로 참조합니다.
#         1.2. 이미 저장되어 있는 '/artifacts' 폴더 내 'prate....png' 도표를 레포트에 최대한 반영해주세요.
#     2. 자동차 생산량 및 거시경제 데이터 분석은 '/artifacts' 폴더 내 'quarterly_aggregated_....csv' 파일을 이해하고 분석하여 인사이트를 도출해주세요.
#         2.1. 이미 분석되어 있는 json 파일은 Cross-correlation, granger causality, variable importance 파일을 참조하여 결론을 도출합니다.
#         2.2. 거시경제 지표와 자동차 생산량의 관계는 'data/fred_dict.json'을 참조하여 설명해주세요.
#         2.3. 이미 저장되어 있는 '/artifacts' 폴더 내 'corr_....png', 'granger_....png', 'rf_test....png' 도표를 레포트에 최대한 반영해주세요.
#     3. 전기차의 가격탄력성 및 시나리오(base/best/worst) 상 수요변화 예상 분석
#         3.1. 전기차의 가격탄력성 분석은 여러 자료를 활용해 자동차의 수요탄력성을 추정해야 합니다.
#         3.2. 관세의 변화로 인해 변경되는 자동차 가격의 변동분과 3.1.에서 추정한 탄력성을 활용해 수요의 변동을 시나리오별로 추정해주세요.
#     4. 레포트 가장 하단에 참고문헌 및 링크 등을 명기해주세요. (Researcher Agent가 모은 자료)
# """

# %%
# user_query="""
# # 제목: 북미(North America) 전기차 시장 분석

# ## 지침:
# # 당신은 LG Energy Solution의 전략 분석가이며 북미 시장의 전기차 배터리 시장에 대한 전략을 수립하고 있습니다.
# # 아래 자동차 생산량 데이터를 활용하여 분석방향에 따라 최종 레포트를 작성하세요. (**최종 레포트는 한국어로 작성**)
# # 레포트의 가장 앞에 Executive Summary를 작성해 주요한 insights를 정리해주세요.
# # 최종 레포트는 최종 결과물과 출처, 도표 등을 이용해 최종 결론을 도출해주세요.

# ### 분석방향
# ## 모든 분석은 가설을 수립하고(시나리오를 수립하고) 그에 따른 검증을 진행해주세요

# ## Researcher Agent
# - 필요하다면 검색전략 작성(json 및 markdown)을 위해 Coder Agent를 활용해주세요.
# - 아래 시나리오 플래닝에 필요한 추가 정보들을 검색하여 추가적으로 정보를 모아주세요.
#     a. 시나리오 플래닝: 트럼프 2기 정부 대중국 관세정책 시행 시 북미 전기차 시장에 미칠 영향
#     b. 분석결과는 2025년부터 2036년까지 P-rate 분석을 위한 자료 (기존 vs. base/best/worst 시나리오)
# - 정보를 모을 때, 반드시 출처를 함께 명기해 주세요.
# - 최근 3달 간의 자료를 중심으로 분석해주세요.

# ## Coder Agent
# - 'artifacts/quarterly_aggregated_....csv'로는 새로운 분석을 할 필요가 없고 기존에 분석된 json 결과파일만 참조해 분석 및 해석에 집중해주세요.
# - 추가적으로 도표/차트 생성을 할 필요는 없습니다.

# ## Reporter Agent
# - 분석을 1. P-rate 분석 및 2. 자동차 생산량 및 거시경제 데이터 분석 및 3. 추가 분석 순으로 진행해주세요.
#     1. P-rate 분석은 '/artifacts' 폴더 내 'prate....json' 파일을 이해하고 분석하여 인사이트를 도출해주세요.
#         1.1. P-rate(penetration rate) 분석은 전체 차량 판매량 대비 전기차(POS(최종) 내에 EV + PHEV)의 비율을 나타낸 지표로, 전기차의 보급률을 파악하는데에 핵심적인 지표이며 Region(최종) 별로 참조합니다.
#         1.2. 이미 저장되어 있는 '/artifacts' 폴더 내 'prate....png' 도표를 레포트에 최대한 반영해주세요.
#     2. 자동차 생산량 및 거시경제 데이터 분석은 '/artifacts' 폴더 내 'quarterly_aggregated_....csv' 파일을 이해하고 분석하여 인사이트를 도출해주세요.
#         2.1. 이미 분석되어 있는 json 파일은 Cross-correlation, granger causality, variable importance 파일을 참조하여 결론을 도출합니다.
#         2.2. 거시경제 지표와 자동차 생산량의 관계는 'data/fred_dict.json'을 참조하여 설명해주세요.
#         2.3. 이미 저장되어 있는 '/artifacts' 폴더 내 'corr_....png', 'granger_....png', 'rf_test....png' 도표를 레포트에 최대한 반영해주세요.
#     3. 전기차의 가격탄력성 및 시나리오(base/best/worst) 상 수요변화 예상 분석
#         3.1. 전기차의 가격탄력성 분석은 여러 자료를 활용해 자동차의 수요탄력성을 추정해야 합니다.
#         3.2. 관세의 변화로 인해 변경되는 자동차 가격의 변동분과 3.1.에서 추정한 탄력성을 활용해 수요의 변동을 시나리오별로 추정해주세요.
#     4. 레포트 가장 하단에 참고문헌 및 링크 등을 명기해주세요. (Researcher Agent가 모은 자료)
# """

# %%
# user_query = """
# # 제목: 북미(North America) 전기차 시장 분석

# ## 지침:
# # 당신은 전기차 시장의 전문 Analyst입니다.
# # 아래 내연기관차-전기차 가격차이(diff)를 cross-correlation, granger causality, price elasticity 등으로 분석해 저장해놓은 json 파일을 분석해주세요. (**최종 레포트는 한국어로 작성**)
# # 레포트의 가장 앞에 Executive Summary를 작성해 주요한 insights를 정리해주세요.
# # 분석의 결과를 정리할 때에는 각 segment별로 정리하되, 필요 시 SUV와 Non-SUV(승용차)로 구분하여 정리해주세요.
# # 최종 레포트는 최종 결과물과 출처, 도표 등을 이용해 최종 결론을 도출해주세요.

# ### 분석방법
# ## 모든 분석은 가설을 수립하고(시나리오를 수립하고) 그에 따른 검증을 진행해주세요

# ## Researcher Agent
# - 필요하다면 검색전략 작성(json 및 markdown)을 위해 Coder Agent를 활용해주세요.
# - 아래 시나리오 플래닝에 필요한 추가 정보들을 검색하여 추가적으로 정보를 모아주세요.
#     a. 내연기관차와 전기차의 가격차이(price parity)에 대한 시장 전반/일반적인 정보
#     b. 내연기관차와 전기차의 가격탄력성(price elasticity)에 대해 조사 및 연구된 자료
# - 정보를 모을 때, 반드시 출처를 함께 명기해 주세요.

# ## Coder Agent 
# - 'artifacts/price_diff.json', 'artifacts/price_elasticity.json' 파일들로는 새로운 분석을 할 필요가 없고 기존에 분석된 json 결과파일만 참조해 분석 및 해석에 집중해주세요. 

# ## Reporter Agent
# - 아래 원칙에 따라 레포트를 작성해주세요.
#     1. 레포트 가장 하단에 참고문헌 및 링크 등을 명기해주세요. (Researcher Agent가 모은 자료)
#     2. 레포트는 가설을 수립하고 검증하는 과학적인 방식으로 작성해주세요.

# """

# %%
# user_query = """
# # 제목 및 주제: 북미(North America) 전기차 시장의 price parity 분석 (Battery Cost 관점에서)

# ## 지침:
# # 당신은 전기차 시장의 전문 Analyst입니다.
# # 주제에 맞추어 계획을 작성하고, 조사를 실시하여 최종 레포트를 작성해주시기 바랍니다.
# # 레포트의 가장 앞에 Executive Summary를 작성해 주요한 insights를 정리해주세요.
# # 최종 레포트는 최종 결과물과 출처, 도표 등을 이용해 최종 결론을 도출해주세요.

# ### 분석방법
# ## 모든 분석은 가설을 수립하고(시나리오를 수립하고) 그에 따른 검증을 진행해주세요.

# ## Researcher Agent
# - 주제에 맞추어 계획을 작성하고, 조사를 실시하여 최종 레포트를 작성해주시기 바랍니다.
# - 필요하다면 검색전략 작성(json 및 markdown)을 위해 Coder Agent를 활용해주세요.
# - 아래 시나리오 플래닝에 필요한 추가 정보들을 검색하여 추가적으로 정보를 모아주세요.
#     a. 내연기관차와 전기차의 가격차이(price parity)에 대한 시장 전반/일반적인 정보
#     b. 내연기관차와 전기차의 가격탄력성(price elasticity)에 대해 조사 및 연구된 자료
#     c. 모든 자료는 분석가의 입장에서 사용할 수 있도록 academic research를 우선순위로 찾고, 전문 기관의 리서치 결과를 인용해도 좋습니다.
# - 정보를 모을 때, 반드시 출처를 함께 명기해 주세요.

# ## Reporter Agent
# - 아래 원칙에 따라 레포트를 작성해주세요.
#     1. 레포트 가장 하단에 참고문헌 및 링크 등을 명기해주세요. (Researcher Agent가 모은 자료)
#     2. 레포트는 가설을 수립하고 검증하는 과학적인 방식으로 작성해주세요.

# """

# %%
user_query = """
# 제목 및 주제: 리튬 개발 프로젝트들의 과거 감산, closed, 보조금 지급 관련 등의 정보 조사(2015~2024)

## 지침:
# 당신은 리튬 원자재 시장의 전문 Analyst입니다.
# 주제에 맞추어 계획을 작성하고, 조사를 실시하여 최종 결과물을 테이블로 정리해 주세요.
# 최종 결과물과 그에 해당하는 출처를 함께 정리해 주세요.

### 분석방법
## 모든 프로젝트들의 2015년부터 현재 까지의 과거 감산, closed(idle), 광산/염호 보조금 지급 여부를 조사하여 정리 합니다. 
## 관련 정보가 없을 경우 없다고 표시 합니다.

## Researcher Agent
- 확인해야 하는 프로젝트명은 'data/LithiumProduction/Project_list_250611.xlsx' 파일에서 project column 을 확인하여 탐색해주세요.
- 주제에 맞추어 계획을 작성하고, 조사를 실시하여 최종 레포트를 작성해주시기 바랍니다.
- 필요하다면 검색전략 작성(json 및 markdown)을 위해 Coder Agent를 활용해주세요.
- 아래 시나리오 플래닝에 필요한 추가 정보들을 검색하여 추가적으로 정보를 모아주세요.
    a. 프로젝트명, 지역별로 과거 감산, closed(idle), 광산/염호 보조금 지급 관련 등의 정보(시점, 내용, 금액 등)
    b. 모든 자료는 News 또는 전문 기관의 리서치 결과를 인용해도 좋습니다.
- 정보를 모을 때, 반드시 출처를 함께 명기해 주세요.

## Reporter Agent
- 아래 원칙에 따라 레포트를 작성해주세요.
    1. 레포트 가장 하단에 참고문헌 및 링크 등을 명기해주세요. (Researcher Agent가 모은 자료)
"""

# %%
import asyncio
from main import execute_query

# nest_asyncio가 필요한 경우
import nest_asyncio

nest_asyncio.apply()

# 쿼리 실행
user_query = user_query.strip()
result = asyncio.run(execute_query(user_query))

# 결과 출력
print("\n=== Conversation History ===")
print("result", result)
for history in result["history"]:
    print("===")
    print(f'agent: {history["agent"]}')
    print(f'message: {history["message"]}')
# Out:
# INFO [src.workflow] ===== Starting workflow =====
#
# INFO [src.workflow]
# user input: # 제목 및 주제: 리튬 개발 프로젝트들의 과거 감산, closed, 보조금 지급 관련 등의 정보 조사(2015~2024)
#
# ## 지침:
# # 당신은 리튬 원자재 시장의 전문 Analyst입니다.
# # 주제에 맞추어 계획을 작성하고, 조사를 실시하여 최종 결과물을 테이블로 정리해 주세요.
# # 최종 결과물과 그에 해당하는 출처를 함께 정리해 주세요.
#
# ### 분석방법
# ## 모든 프로젝트들의 2015년부터 현재 까지의 과거 감산, closed(idle), 광산/염호 보조금 지급 여부를 조사하여 정리 합니다.
# ## 관련 정보가 없을 경우 없다고 표시 합니다.
#
# ## Researcher Agent
# - 확인해야 하는 프로젝트명은 'data/LithiumProduction/Project_list_250611.xlsx' 파일에서 project column 을 확인하여 탐색해주세요.
# - 주제에 맞추어 계획을 작성하고, 조사를 실시하여 최종 레포트를 작성해주시기 바랍니다.
# - 필요하다면 검색전략 작성(json 및 markdown)을 위해 Coder Agent를 활용해주세요.
# - 아래 시나리오 플래닝에 필요한 추가 정보들을 검색하여 추가적으로 정보를 모아주세요.
#     a. 프로젝트명, 지역별로 과거 감산, closed(idle), 광산/염호 보조금 지급 관련 등의 정보(시점, 내용, 금액 등)
#     b. 모든 자료는 News 또는 전문 기관의 리서치 결과를 인용해도 좋습니다.
# - 정보를 모을 때, 반드시 출처를 함께 명기해 주세요.
#
# ## Reporter Agent
# - 아래 원칙에 따라 레포트를 작성해주세요.
#     1. 레포트 가장 하단에 참고문헌 및 링크 등을 명기해주세요. (Researcher Agent가 모은 자료)
# ...
