# %% [markdown]
# # 1. One video sample test
# > *setting the environment and making helper functions*

# %% [markdown]
# ## 1.1 Import packages and prepare a sample json file

# %%
import json
import os
from tqdm import tqdm
from datetime import datetime

import boto3
from langchain_aws import ChatBedrock
from langchain.prompts import PromptTemplate
from langchain_core.prompts import ChatPromptTemplate
from langchain.chains import create_tagging_chain
# from langchain.chains import LLMChain, SequentialChain
from langchain_core.runnables import RunnableSequence
from langchain_core.output_parsers import JsonOutputParser, CommaSeparatedListOutputParser, StrOutputParser

# %%
### Set a specific json file to analyze and set keywords between 'LITHIUM INVESTMENT' and 'LITHIUM SUPPLY CHAIN'
file_path = 'jsons/lithium supply chain/2018-01-08.json'
keyword = 'LITHIUM SUPPLY CHAIN'

# %% [markdown]
# ## 1.2 Set helper functions

# %% [markdown]
# ### 1.2.1 Get a full transcripts from one video

# %%
def get_full_caption(video):
    video_id = video['id']['videoId']

    text = " ".join([item['text'] for item in video['caption']])
    text = text.replace("[Music]","")
    text = text.replace("[음악]","")
    text = text[:760000]

    if len(text) < 10:
        text = "No caption available"
    return text

# %% [markdown]
# ### 1.2.2 Make a Bedrock object

# %%
def call_bedrock(**kwargs):
    bedrock_runtime = boto3.client(
        service_name="bedrock-runtime",
        region_name="us-east-1",
    )
    # model_id = "anthropic.claude-3-sonnet-20240229-v1:0" # Claude 3 Sonnet
    # model_id = "anthropic.claude-3-haiku-20240307-v1:0" # Claude 3 Haiku
    # model_id = "meta.llama3-8b-instruct-v1:0" # Llama3-8b Instruct
    model_id = "anthropic.claude-3-5-sonnet-20240620-v1:0"


    model_kwargs =  { 
        # Reference: https://docs.aws.amazon.com/bedrock/latest/userguide/inference-parameters.html
        "max_tokens": 10000,
        "temperature": 0.01,
        "top_p": 0.9
    }
    
    llm = ChatBedrock(
        client=bedrock_runtime,
        model_id=model_id,
        model_kwargs=model_kwargs,
    )

    return llm

# %% [markdown]
# ### 1.2.3 Check whether the input text has a relevance to the subject or not

# %%
def check_relevance(llm, text:str, subject:str='LITHIUM MARKET', verbose=False) -> str:
    """get_intend _summary_

    Args:
        text (str): _description_
        args (_type_): _description_

    Returns:
        str: _description_
    """

    template = """

    <paper>
    {text}
    </paper>
    
    [Task instructions]
    here is a paper above. 
    read the paper and determine whether the content is related to the {subject}. \
    If the content is related to the {subject}, please **just** say ‘yes’,
    IF the content is not related to the {subject}, please **just** say ‘no’. \
    You must follow this format. \
    
    result: ‘yes’ \
    result: ‘no’ \

    result: 
    """

    prompt = PromptTemplate(template=template, input_variables=['subject', 'text'])
    chain = prompt | llm
    intend = chain.invoke({'subject':subject, 'text':text}).content
    YesOrNo = intend.lower().replace(' ','').replace('result:','')
    
    if verbose==False:
        return YesOrNo
    else:
        template2 = """
        <paper>
        {text}
        </paper>
        
        [Task instructions]
        here is a paper above. 
        read the paper and determine whether the content is related to the {subject}. \
        If the content is related to the {subject}, please provide the reason,
        IF the content is not related to the {subject}, please **just** say ‘No reason’. \
        You must follow this format. \
        
        result: ‘It's related to {subject} since ...’ \
        result: ‘no’ \

        result: 
        """

        prompt = PromptTemplate(template=template2, input_variables=['subject', 'text'])
        chain = prompt | llm
        intend = chain.invoke({'subject':subject, 'text':text}).content
        reason = intend.lower()
        return "Answer: " + YesOrNo + "\n" + "Reason: " + reason

# %% [markdown]
# ### 1.2.4 Get a summary of text

# %%
def get_summary(llm, text: str, subject: str = 'LITHIUM MARKET') -> str:
    template = '''
    Here is an article. 
    Read the article carefully and summarise the information related to {subject} using the [Task instructions]:

    [Task instructions]
    1. if you have specific numerical information, please use it in your summary.
    2. Use proper nouns in their original language.
    3. Summarize the information related to {subject}, focusing on the main points.
    4. Please give me the only summary without your comment or unnecessary information.
    
    <paper>
    {text}
    </paper>
    '''
    prompt = PromptTemplate(template=template, input_variables=['subject', 'text'])
    chain = prompt | llm
    response = chain.invoke({'subject':subject, 'text':text}).content
    
    return response

# %% [markdown]
# ### 1.2.5 Extract some related sentences from the text given that the keyword is provided

# %%
def extract_sentences_with_keyword(llm, text: str, keyword: str) -> str:
    """
    Extracts sentences containing a specific keyword from a given text and returns them as bullet points.
    """
    output_parser = JsonOutputParser()
    format_instructions = output_parser.get_format_instructions()
    
    template = '''
    Here is an article.
    Read the article carefully and extract sentences that contain the keyword "{keyword}".
    Present each sentence as a bullet point in the following format:

    [Task instructions]
    1. Extract only the sentences that contain the keyword "{keyword}".
    2. Ensure each bullet point contains only one sentence.
    3. Do not modify the original sentences.
    4. If there are no related sentences, write "No related sentences".
    5. Please provide your own reason for your answer and follow the format below.
    6. ** Most Important ** : Please provide only answer in json format without any additional comment of you.

    <paper>
    {text}
    </paper>

    {format_instructions}
    Make a dictionary with the key 'sentence' and value as a list of sentence.
    Also add key 'reason' and value as a list of reasons.
    For example {{'sentence': ['sentence1.', sentence2', 'sentence3', ...], 'reason': ['reason1', 'reason2', 'reason3', ...]}}
    If there's no related sentences, provide me {{'sentence': ["No related sentences"]}}
    '''
    
    prompt = PromptTemplate(
        template=template,
        input_variables=['keyword', 'text'],
        partial_variables={"format_instructions": format_instructions}
    )
    
    chain = prompt | llm | output_parser

    try:
        result = chain.invoke({"text": text, "keyword": keyword})
        sentences = result.get('sentence', [])
        reasons = result.get('reason', [])
        if sentences==[]:
            return "- No related sentences"
        answer_s = '\n'.join(f'- {sentence}' for sentence in sentences)
        answer_r = '\n'.join(f'- {reason}' for reason in reasons)
        return '* Sentences from the original transcripts: \n' + answer_s + '\n' + '* Reasons by LLM: \n' + answer_r
    except Exception as e:
        return str(e)

# %% [markdown]
# ### 1.2.6 Test helper functions with one video sample

# %% [markdown]
# >check 10 videos in one json file whether each video has a relevance with the lithium investment or not

# %%
## temp
### Set a specific json file to analyze and set keywords between 'LITHIUM INVESTMENT' and 'LITHIUM SUPPLY CHAIN'
file_path = 'jsons/lithium supply chain/2023-06-16.json'
keyword = 'LITHIUM SUPPLY CHAIN'
subject = 'LITHIUM OR BATTERY MARKET'

# %%
sample_data = json.load(open(file_path))

# %%
for i in range(len(sample_data[keyword])):
    llm = call_bedrock()

    print(f'\n[Sample Video {i+1}: ]\n')
    sample_caption = get_full_caption(sample_data[keyword][i])
    summary = get_summary(llm, sample_caption, subject=subject)

    print('\t', summary)
    print('\n[RELATED to keyword?: ]', check_relevance(llm, sample_caption, subject=subject, verbose=True), '\n')
    print('==========================================================================')
# Out:
# [Sample Video 1: ]
#
# 	 Summary of information related to the lithium or battery market:
#
# Nickel is a crucial component in electric vehicle (EV) batteries, prized for increasing the range of EVs. Indonesia has become the world's largest nickel producer, with about half of the global nickel currently mined there. By 2027, analysts predict that approximately 80% of the global nickel supply used in EV batteries will come from Indonesia. The country's nickel is attractive to car makers because it's found close to the surface, making extraction relatively cheap compared to deep underground mining in countries like Canada and Russia. However, the extraction process in Indonesia, often using high-pressure acid leaching, is about twice as carbon-intensive as methods used elsewhere. This process leaves behind large amounts of waste and poses environmental risks, particularly to pristine ecosystems and coral reefs surrounding the mining areas. Despite these concerns, Indonesia's government sees nickel as a way to move up the value chain in the global EV battery supply chain, restricting nickel exports to encourage in-country processing and potentially battery and car manufacturing.
#
# [RELATED to keyword?: ] Answer: 'yes'
# Reason: result: it's related to lithium or battery market since the paper discusses nickel mining and production in indonesia, which is directly linked to the battery market for electric vehicles. the content explains how nickel is an essential component for ev batteries, increasing their range and energy density. it also highlights the environmental concerns surrounding nickel extraction and its importance in the global supply chain for ev batteries.
#
# ==========================================================================
#
# [Sample Video 2: ]
#
# 	 Here's a summary of the information related to the lithium and battery market from the article:
#
# 1. Lithium is a critical component in electric vehicle (EV) batteries, with global reserves estimated at 26 million tons.
#
# 2. Australia is the largest lithium producer (6.2-9.3 million tons), followed by Chile and China.
#
# 3. Two main types of lithium sources: brine (from Chile) and spodumene (hard rock from Australia).
#
# 4. China dominates lithium processing, with 60% of global capacity, while Chile has 27% and Argentina 8%.
#
# 5. 80% of lithium production is used for batteries.
#
# 6. A supply gap is expected to emerge between 2024-2026, with demand outpacing production and recycling.
#
# 7. Key lithium manufacturers include Albemarle, SQM, Livent Corporation, Ganfeng Lithium, and Tianqi Lithium.
#
# 8. Lithium prices have dropped 34% from their peak in 2021.
#
# 9. EV batteries typically contain 8kg of lithium carbonate, along with nickel, manganese, and cobalt in varying ratios.
#
# 10. Battery cell manufacturing is concentrated in China (80% of production).
#
# 11. The value obtained from lithium mining is low (about 1%), with most value coming from processing, cell production, and battery assembly.
#
# 12. Western countries need to urgently focus on securing lithium processing capacity to compete with China's dominance.
#
# [RELATED to keyword?: ] Answer: 'yes'
# Reason: it's related to lithium or battery market since the paper extensively discusses lithium and battery metals as part of the energy transition and electric vehicle (ev) industry. it covers topics such as:
#
# 1. the composition of ev batteries, including lithium, nickel, manganese, and cobalt.
# 2. lithium production, processing, and supply chain details.
# 3. the growing demand for lithium in batteries (80% of lithium production goes to batteries).
# 4. supply and demand projections for lithium, indicating potential shortages in the future.
# 5. key lithium producers and processors globally.
# 6. the importance of battery metals like copper in the energy transition and ev industry.
#
# the paper provides a comprehensive overview of the lithium and battery metal markets, making it highly relevant to the topic.
#
# ==========================================================================
#
# [Sample Video 3: ]
#
# 	 Summary of information related to lithium or battery market:
#
# Electro Battery Materials, a Canadian company, is set to commission a refinery in Northern Ontario that will produce cobalt sulfate. They will be the only facility in North America producing this key material for batteries, making them an important part of the EV supply chain in North America. The company is also running a recycling demo plant that can recover nickel, lithium, manganese, and cobalt from used batteries. Their refinery is expected to be commissioned in spring of the following year. The company aims to be ethical, traceable, and low-carbon in its operations, focusing on sustainability and ESG (Environmental, Social, and Governance) principles. They are working on implementing traceability software to track their products from suppliers to customers, with automation playing a key role in data collection and performance tracking.
#
# [RELATED to keyword?: ] Answer: 'yes'
# Reason: it's related to lithium or battery market since the paper discusses electro battery materials, a company that produces cobalt sulfate for batteries and is involved in battery recycling. the company is described as an important part of the ev (electric vehicle) supply chain in north america, which directly relates to the battery market. additionally, the paper mentions lithium recovery in their recycling process, which is a key component of batteries.
#
# ==========================================================================
#
# [Sample Video 4: ]
#
# 	 Summary of lithium and battery market information:
#
# U.S. car manufacturers have domestic options for sourcing lithium, a key component in electric vehicle batteries. These include:
#
# 1. Mining: Opening new mines and potentially reopening viable former mines, such as one in North Carolina, pending permit approval.
#
# 2. Recycling: Processing production scrap and used EV batteries. The Ascend Elements battery recycling facility in Georgia can process 30,000 metric tons of input annually, equivalent to breaking down battery packs from 70,000 electric vehicles.
#
# With U.S. EV sales expected to exceed 1 million units this year, addressing supply chain concerns is crucial. The lithium sourcing options mentioned provide potential solutions to meet the growing demand for EV batteries.
#
# [RELATED to keyword?: ] Answer: 'yes'
# Reason: it's related to lithium or battery market since the paper discusses lithium sourcing options for u.s. car manufacturers, specifically for electric vehicle batteries. it mentions lithium mining, reopening old lithium mines, and recycling ev batteries to extract lithium. the content also touches on battery recycling facilities and the growing demand for lithium due to increasing ev sales, which are all directly related to the lithium and battery market.
#
# ==========================================================================
#
# [Sample Video 5: ]
#
# 	 Summary of information related to LITHIUM OR BATTERY MARKET:
#
# Tesla's new Gigafactories in Germany and Texas are experiencing significant financial losses, described by CEO Elon Musk as "gigantic money furnaces." These losses are primarily attributed to global supply chain disruptions, which have been particularly severe over the past three years. The supply chain issues are affecting Tesla's ability to ramp up production at these new plants, resulting in billions of dollars in losses.
#
# [RELATED to keyword?: ] Answer: 'yes'
# Reason: result: it's related to lithium or battery market since the paper discusses tesla, which is a major electric vehicle manufacturer. electric vehicles rely heavily on lithium-ion batteries, so any issues affecting tesla's production, such as the mentioned supply chain disruptions and financial losses at new factories, could potentially impact the demand for lithium and batteries in the automotive sector.
#
# ==========================================================================
#
# [Sample Video 6: ]
#
# 	 Here is a summary of the key information related to the lithium and battery market from the article:
#
# 1. The global lithium and battery market is still in its early stages, with significant growth potential ahead.
#
# 2. Electric vehicle (EV) adoption is a key driver of lithium demand. EV penetration rates are increasing rapidly in countries like China, with 5% penetration seen as a tipping point for accelerated growth.
#
# 3. Lithium supply is expected to remain in deficit for the next few years, despite increasing production. Forecasts suggest deficits will continue into the near future.
#
# 4. Lithium prices saw a significant pullback in 2022-2023 after reaching highs in 2021, but are showing signs of stabilization. Analysts expect prices to remain above $40/kg.
#
# 5. The lithium supply chain includes mining companies, battery manufacturers, and EV makers. Major players include Albemarle, Ganfeng, Tesla, BYD, and Panasonic.
#
# 6. Government policies and regulations, particularly in Europe and China, are driving EV adoption and lithium demand.
#
# 7. Challenges include the need for more mining projects to come online, which requires significant capital investment. Higher interest rates are increasing the cost of capital for new projects.
#
# 8. While lithium is not rare, extracting it economically can be challenging. Regulatory risks in some countries, like potential nationalization in South America, could impact supply.
#
# 9. The U.S. Inflation Reduction Act and EU Critical Raw Materials Act aim to support domestic lithium and battery supply chains in those regions.
#
# [RELATED to keyword?: ] Answer: 'yes'
# Reason: result: it's related to lithium or battery market since the paper discusses the global end-to-end supply chain for batteries, lithium, and electric vehicles (evs). it covers topics such as the growing demand for lithium due to ev adoption, the lithium market outlook, battery technology, and investment opportunities in the lithium and battery sector. the presentation includes information on lithium supply and demand, price trends, and the role of lithium in battery production for electric vehicles.
#
# ==========================================================================
#
# [Sample Video 7: ]
#
# 	 I apologize, but this article does not contain any information related to the lithium or battery market. The text primarily discusses a tanker truck crash on I-95 in Philadelphia that led to the collapse of an overpass, its impact on traffic and supply chains, and the ongoing efforts to address the situation. There is no mention of lithium or batteries in this content.
#
# [RELATED to keyword?: ] Answer: 'no'
# Reason: result: 'no'
#
# ==========================================================================
#
# [Sample Video 8: ]
#
# 	 Here's a summary of the key points related to the lithium and battery market from the article:
#
# 1. Lithium use in batteries has increased significantly, now accounting for about 75% of lithium demand compared to only 33% in 2011.
#
# 2. Lithium is crucial for electric vehicle (EV) batteries due to its high energy density, with a 60 kWh battery pack using about 9 kg of lithium.
#
# 3. Lithium prices have spiked dramatically in recent years, with lithium hydroxide, lithium carbonate, and lithium metal prices all increasing significantly.
#
# 4. There are concerns about lithium scarcity, leading some automakers to secure materials 3-5 years in advance and consider vertical integration into lithium mining and refining.
#
# 5. Global lithium demand is expected to grow rapidly, with Bloomberg NEF projecting significant increases across sectors like EVs, stationary storage, and consumer electronics through 2030.
#
# 6. Current lithium production is primarily concentrated in Australia, Chile, and China, but production capacity is not increasing fast enough to meet projected demand.
#
# 7. The development of new lithium mining and refining facilities is a slow process, potentially leading to supply shortages in the near to medium term.
#
# 8. Recent cancellations or delays in planned battery gigafactories have temporarily eased some supply pressures, but long-term demand growth is still expected to outpace supply.
#
# [RELATED to keyword?: ] Answer: 'yes'
# Reason: it's related to lithium or battery market since the paper discusses various aspects of lithium and its use in batteries, including:
#
# 1. the importance of lithium in battery technology
# 2. why lithium is used in batteries (energy density, performance characteristics)
# 3. the growing demand for lithium due to electric vehicle batteries
# 4. lithium pricing and supply chain issues
# 5. different lithium battery chemistries and their efficiencies
# 6. global lithium production and demand forecasts
# 7. challenges in lithium mining, refining, and recycling
#
# the paper provides an overview of the lithium and battery market, discussing technical aspects, economic factors, and future outlook for the industry.
#
# ==========================================================================
#
# [Sample Video 9: ]
#
# 	 Summary of information related to LITHIUM OR BATTERY MARKET:
#
# The lithium-ion battery supply chain is becoming increasingly complex, with new routes emerging for nickel production. Batteries are expected to become more important than stainless steel for nickel demand by the end of this decade. The demand for nickel sulfate, a key component in lithium-ion batteries, is growing rapidly.
#
# Indonesia is a major player in nickel production, expected to increase its share of global nickel production from 40% to about 60% by 2030. The country's nickel production could triple from just over 1 million tons in 2022 to upwards of 3 million tons by the end of the decade.
#
# Battery demand is projected to grow significantly, with expectations to exceed 6 terawatt-hours over the next 10-15 years, primarily driven by electric vehicles. This growth is driving demand for all battery materials, including nickel, cobalt, and lithium.
#
# The nickel market is expected to shift from a period of surplus to deficit from the mid to late 2020s, which will likely support price growth in the coming years. The market size for nickel is projected to double over the next decade, primarily driven by battery demand.
#
# There is increasing investment from downstream companies into upstream raw material sources to secure supply for the growing battery demand. Major automakers are actively securing raw materials in anticipation of the demand surge.
#
# [RELATED to keyword?: ] Answer: 'yes'
# Reason: it's related to lithium or battery market since the paper discusses nickel's role in lithium-ion batteries, the growing demand for nickel in the battery sector, and how this is impacting the nickel market. the presentation covers topics such as nickel sulfate production for batteries, the shift in nickel demand from stainless steel to batteries, and how the battery industry is driving investments in nickel production. it also mentions the overall growth in battery demand, particularly for electric vehicles, which is directly related to the lithium and battery market.
#
# ==========================================================================
#
# [Sample Video 10: ]
#
# 	 Here is a summary of the key information related to the lithium and battery market from the article:
#
# 1. The lithium and battery market is still in its early stages of growth, with electric vehicle (EV) adoption being a key driver of demand.
#
# 2. Global EV penetration rates vary significantly by country, with Nordic countries leading adoption. China is seen as a crucial market that will drive outcomes for lithium and battery technology.
#
# 3. A 5% EV penetration rate is generally seen as a tipping point for accelerated adoption. China has passed this threshold and is expected to see rapid growth in the coming years.
#
# 4. Lithium supply deficits are expected to continue for the next few years despite increasing production, supporting prices.
#
# 5. Lithium prices have pulled back significantly from 2022 highs but are stabilizing at levels that support battery and EV production.
#
# 6. Major automakers are rapidly expanding EV production and model offerings, driving demand throughout the battery supply chain.
#
# 7. The lithium and battery thematic is viewed as a long-term investment opportunity, with the market still in early stages of a multi-year growth trend.
#
# 8. Government policies and regulations, particularly in Europe and China, are supporting the transition to EVs and driving demand for lithium and batteries.
#
# 9. The broader shift toward decarbonization is expected to support long-term demand for lithium, batteries, and related materials.
#
# [RELATED to keyword?: ] Answer: 'yes'
# Reason: result: it's related to lithium or battery market since the paper discusses the global end-to-end supply chain for batteries, lithium, and electric vehicles (evs). it covers topics such as the lithium market, battery technology, ev adoption rates, and investment opportunities in the lithium and battery sector. the presentation includes information on lithium supply and demand, battery manufacturing, and the role of lithium in the transition to electric vehicles. it also discusses investment products that provide exposure to the lithium and battery market, including etfs and structured investment products.
#
# ==========================================================================

# %% [markdown]
# >now check all the functions with only one video samples

# %%
sample_caption = get_full_caption(sample_data[keyword][1])

# %%
print('[Original transcript]', '\n', sample_caption)
# Out:
# [Original transcript]
#  our commodity race continues I hope you're entertained guys I made eight videos about uranium I brought the biggest uranium buyer in the world here to the office and you heard what he said now uranium broke out is up by a lot and it followed this trend line exactly and to those who say that Commodities are boring because price movements are small remember that unlike altcoins Commodities you can definitely trade successfully with leverage there are wheat Futures with 500x leverage and there are commodity companies that can go 100x thousand X so boring it's just not the correct term congrats to everyone who paid attention and maybe took our course with the commodity scope now with cryptos dwelling and chopping in the wake of regulatory attacks from the SEC in the US I hope you see the power of true diversification and today we continue a few weeks ago I covered oil and gas today it's an episode I'm really looking forward to myself battery Metals given the volume of information we will be keeping this session focused but please realize that it will be dense and it will be lengthy so grab your coffee and let's go first we will talk about the general energy thesis then we will outline how a typical EV battery is made up and how battery Metals fit in to this thesis and finally we will outline for each of the various battery methods what the demand and Supply characteristics are what jurisdictional issues and risks there are where to focus and some of the key players in the market I would love your input and feedback please comment below first let's look at the access we have to energy and energy consumption varies a lot across the world we are all used to using dishwashers laundry machines dryers TVs radios fridges computers electric cores you name it all the electronics we use and the massive increase in electronics we have seen over the past 20 years result in a significant electricity usage for those of us who can afford it the average consumption and has increased by approximately 45 percent moreover we've seen a tremendous growth in developing countries and China's per capita use has grown 250 percent since year 2000. India's usage has grown 50 percent and Brazil's usage has grown 38 however compared to the usage in the western economy there is still a long way to go a typical American uses 10 times the average Indian five times the average Brazilian and three times the average Chinese citizen so clearly the trend of energy usage growth will continue essentially we have 8 billion people on Earth and two of those have access to intermittent energy and one billion has no access to energy at all for the 5 billion who have access to energy all of them want the same energy usage as the west and nobody is going to stop them if you look at how much is being invested in clean energy we see it's a lot it's like a trillion then if you look at the impact that has had on the overall and energy consumption renewable energy consumption present to Total final energy consumption while we can see that this is growing even though this is a few years old if you look at actual numbers here on the side we see that it's not growing on that fast pace if spent per year is 1 trillion you probably need to spend another like 5 trillion for each percentage Point gain here also as we covered in previous videos oil and gas is also going up uranium is going up yearly and coal having its highest consumption in 2022 ever with 8.3 billion tons this all makes sense all developing countries are looking to develop further and that requires energy they want to live like you and I and because of that in the foreseeable future we will see an ongoing use of fossil fuels coal and so on probably 2023 will hit another peak in Coal usage but of course that also means that there is a very fast growing Market focused on energy transition green energy renewable energy and that means that there will be a lot lot more focus on supply distribution and storage of energy all of ...

# %%
llm = call_bedrock()
keyword = "LITHIUM SUPPLY CHAIN"

print(f'[Is this video related to {subject}?]')
print(check_relevance(llm, sample_caption, subject=subject, verbose=True), '\n')

print('=='*10)

print('[Summary of video]')
print(get_summary(llm, sample_caption, subject=subject), '\n')

print('=='*10)

print('[Supply related sentences]')
print(extract_sentences_with_keyword(llm, sample_caption, 'LITHIUM SUPPLY CHAIN'), '\n')

print('=='*10)

print('[Demand related sentences]')
print(extract_sentences_with_keyword(llm, sample_caption, 'LITHIUM DEMAND ON MARKET'), '\n')

print('=='*10)

print('[Investment related sentences]')
print(extract_sentences_with_keyword(llm, sample_caption, 'INVESTMENT ON LITHIUM'), '\n')
# Out:
# [Is this video related to LITHIUM OR BATTERY MARKET?]
# Answer: 'yes'
# Reason: it's related to lithium or battery market since the paper extensively discusses lithium and battery metals as part of the energy transition and electric vehicle (ev) industry. it covers topics such as:
#
# 1. the composition of ev batteries, including lithium, nickel, manganese, and cobalt.
# 2. lithium production, processing, and supply chain details.
# 3. the growing demand for lithium in batteries (80% of lithium production goes to batteries).
# 4. supply and demand projections for lithium, indicating potential shortages in the future.
# 5. discussion of other battery metals like copper and their roles in the battery and ev markets.
#
# the paper provides a comprehensive overview of the lithium and battery metal markets, making it highly relevant to the topic.
#
# ====================
# [Summary of video]
# Here's a summary of the information related to the lithium and battery market from the article:
#
# 1. Lithium is a critical component in electric vehicle (EV) batteries, with global reserves estimated at 26 million tons.
#
# 2. Australia is the largest lithium producer (6.2-9.3 million tons), followed by Chile and China.
#
# 3. Two main types of lithium sources: brine (from Chile) and spodumene (hard rock from Australia).
#
# 4. China dominates lithium processing, with 60% of global capacity, while Chile has 27% and Argentina 8%.
#
# 5. 80% of lithium production is used for batteries.
#
# 6. A supply gap is expected to emerge between 2024-2026, with demand outpacing production and recycling.
#
# 7. Key lithium manufacturers include Albemarle, SQM, Livent Corporation, Ganfeng Lithium, and Tianqi Lithium.
#
# 8. Lithium prices have dropped by 34% from their peak in 2021.
#
# 9. EV batteries typically contain 8kg of lithium carbonate, along with nickel, manganese, and cobalt in varying ratios.
#
# 10. Battery cell manufacturing is concentrated in China (80% of production).
#
# 11. The value obtained from the mining stage is low (about 1%), with most value coming from processing, cell production, and battery assembly.
#
# ====================
# [Supply related sentences]
# * Sentences from the original transcripts:
# - No related sentences
# * Reasons by LLM:
# - The article does not contain any sentences with the exact phrase 'LITHIUM SUPPLY CHAIN'. While the article discusses lithium and its role in batteries, it does not specifically use this exact phrase.
#
# ====================
# [Demand related sentences]
# * Sentences from the original transcripts:
# - No related sentences
# * Reasons by LLM:
# - The article does not contain any sentences with the exact phrase 'LITHIUM DEMAND ON MARKET'. While the article discusses lithium and its role in batteries and the market, it does not use this specific phrase.
#
# ====================
# [Investment related sentences]
# * Sentences from the original transcripts:
# - No related sentences
# * Reasons by LLM:
# - The article does not contain any sentences with the exact phrase 'INVESTMENT ON LITHIUM'. While the article discusses lithium and its role in batteries and the energy transition, it does not specifically mention investments in lithium using the exact phrase specified.

# %% [markdown]
# # 2. Extract impact scores (under the construction)

# %% [markdown]
# ## 2.1 Set a output schema (json)

# %%
schema = {
    "properties": {
        "target": {
            "type": "string",
            "enum": ["demand quantity", "supply quantity", "price"],
            "description": "Specifies whether the information relates to the increase or decrease of the demand quantity, supply quantity, or price of lithium for battery production."
        },
        "target_condition": {
            "type": "string",
            "enum": ["increase", "decrease", "neutral"],
            "description": "Describes whether the text indicates an increase, decrease, or neutral outlook for the specified target in the lithium market."
        },
        "target_reason": {
            "type": "string",
            "description": "Describes the reason behind the impact on the target. If there is no significant impact, state 'There is no significant/direct impact'."
        },
        "influential_keywords": {
            "type": "array",
            "items": {
                "type": "string"
            },
            # "description": "List the top keywords that have the greatest influence on the target's condition. Include up to three keywords. If there is no significant impact, state 'None'."
            "description": '''Finds and ranks up to the top five key-word chunks or phrasal verbs that have a strong impact on the target's situation. 
                            For example, if there's relationship such as A -> B, and B is target, A is influential keyword.
                            Or if there's relationship such as A -> B -> C, and C is target, A and B are influential keywords.
                            Please exclude target itself or equivalent words from the list.
                            This selection should be based on a qualitative assessment to determine if there is a direct influence or a causal relationship between the keyword and the market changes. 
                            Keywords should be chosen only if they are inferred to have a direct causal impact on the target’s increase, decrease, or stability. 
                            This process involves analyzing the context in which these keywords appear, assessing the strength of association, and considering the immediacy of their impact. 
                            If no keywords meet these criteria, state 'None'.
                            '''
        },


        "price_impact": {
            "type": "integer",
            "enum": [0, 1, 2],
            "description": "Describes the short-term impact on lithium prices. A higher score indicates a greater impact. If there is no significant/direct impact, the score should be close to 0."
        },
        "price_condition": {
            "type": "string",
            "enum": ["increase", "decrease", "neutral"],
            "description": "Describes whether the text indicates an increase, decrease, or neutral outlook for the price in the short-term lithium market."
        },
        "price_reason": {
            "type": "string",
            "description": "Describes the reason behind the price impact. If there is no significant impact, state 'There is no significant/direct impact'."
        },

        "demand_impact": {
            "type": "integer",
            "enum": [0, 1, 2],
            "description": "Describes the short-term impact on the demand quantity for lithium. A higher score indicates a greater impact. If there is no significant/direct impact, the score should be close to 0."
        },
        "demand_condition": {
            "type": "string",
            "enum": ["increase", "decrease", "neutral"],
            "description": "Describes whether the text indicates an increase, decrease, or neutral outlook for the market demand quantity in the short-term lithium market."
        },
        "demand_reason": {
            "type": "string",
            "description": "Describes the reason behind the demand impact. If there is no significant impact, state 'There is no significant/direct impact'."
        },

        "supply_impact": {
            "type": "integer",
            "enum": [0, 1, 2],
            "description": "Describes the short-term impact on the supply quantity of lithium. A higher score indicates a greater impact. If there is no significant/direct impact, the score should be close to 0."
        },
        "supply_condition": {
            "type": "string",
            "enum": ["increase", "decrease", "neutral"],
            "description": "Describes whether the text indicates an increase, decrease, or neutral outlook for the supply quantity in the short-term lithium market."
        },
        "supply_reason": {
            "type": "string",
            "description": "Describes the reason behind the supply impact. If there is no significant impact, state 'There is no significant/direct impact'."
        }
    },
    "required": ["target", "target_condition", "target_reason", "influential_keywords", "price_impact", "price_condition", "price_reason", "demand_impact", "demand_condition", "demand_reason", "supply_impact", "supply_condition", "supply_reason"]
}

# %%
# schema = {
#     "properties": {
#         "target": {
#             "type": "string",
#             "enum": ["demand quantity", "supply quantity", "price"],
#             "description": "Specifies whether the information relates to the increase or decrease of the demand quantity, supply quantity, or price of lithium for battery production."
#         },
#         "target_condition": {
#             "type": "string",
#             "enum": ["increase", "decrease"],
#             "description": "Describes whether the text indicates an increase, decrease outlook for the specified target in the lithium market."
#         },
#         "influential_keywords": {
#             "type": "array",
#             "items": {
#                 "type": "string"
#             },
#             # "description": "List the top keywords that have the greatest influence on the target's condition. Include up to three keywords. If there is no significant impact, state 'None'."
#             "description": '''Finds and ranks up to the top five key-word chunks or phrasal verbs that have a strong impact on the target's situation. 
#                             For example, if there's relationship such as A -> B, and B is target, A is influential keyword.
#                             Or if there's relationship such as A -> B -> C, and C is target, A and B are influential keywords.
#                             Please exclude target itself or equivalent words from the list.
#                             This selection should be based on a qualitative assessment to determine if there is a direct influence or a causal relationship between the keyword and the market changes. 
#                             Keywords should be chosen only if they are inferred to have a direct causal impact on the target’s increase, decrease, or stability. 
#                             This process involves analyzing the context in which these keywords appear, assessing the strength of association, and considering the immediacy of their impact. 
#                             If no keywords meet these criteria, state 'None'.
#                             '''
#         },


#         "price_impact": {
#             "type": "integer",
#             "enum": [1],
#             "description": "Describes the short-term impact on lithium prices. A higher score indicates a greater impact. If there is no significant/direct impact, the score should be close to 0."
#         },
#         "price_condition": {
#             "type": "string",
#             "enum": ["increase", "decrease"],
#             "description": "Describes whether the text indicates an increase, decrease outlook for the price in the short-term lithium market."
#         },
#         "demand_impact": {
#             "type": "integer",
#             "enum": [1],
#             "description": "Describes the short-term impact on the demand quantity for lithium. A higher score indicates a greater impact. If there is no significant/direct impact, the score should be close to 0."
#         },
#         "demand_condition": {
#             "type": "string",
#             "enum": ["increase", "decrease"],
#             "description": "Describes whether the text indicates an increase, decrease outlook for the market demand quantity in the short-term lithium market."
#         },
#         "supply_impact": {
#             "type": "integer",
#             "enum": [1],
#             "description": "Describes the short-term impact on the supply quantity of lithium. A higher score indicates a greater impact. If there is no significant/direct impact, the score should be close to 0."
#         },
#         "supply_condition": {
#             "type": "string",
#             "enum": ["increase", "decrease"],
#             "description": "Describes whether the text indicates an increase, decrease outlook for the supply quantity in the short-term lithium market."
#         },

#     },
#     "required": ["target", "target_condition", "influential_keywords", "price_impact", "price_condition", "demand_impact", "demand_condition", "supply_impact", "supply_condition"]
# }

# %% [markdown]
# ## 2.2 Set a prompt to LLM and chain

# %%
# Define the prompt template
### This part should be revised by DG ###

prompt_template = """
Please remember that you must give me the output in JSON format according to the schema provided.
Never include any additional text in the output.

You are an analyst researching the electric vehicle market and battery-related industries.
The following information pertains to the lithium market for battery production and its short-term outlook (within the next three months).
Again, **Very important**: Please return only the JSON output without any additional text such as "Here is the output in JSON format according to the provided schema:"

You are required to analyze the text and provide a structured summary based on the following schema:
Here is the schema (guideline for the output):
{schema}

Please provide the output strictly in JSON format according to the schema provided.
**Very important**: Please return only the JSON output without any additional text such as "Here is the output in JSON format according to the provided schema:"

Input Text: 
{input_text}
"""

prompt = PromptTemplate(template=prompt_template, input_variables=['schema', 'input_text'])

# %%
# Use JsonOutputParser for the final chain
json_output_parser = JsonOutputParser()
output_parser = StrOutputParser()

# Create the runnable sequence
# chain = prompt | llm | json_output_parser
chain = prompt | llm | output_parser

# %% [markdown]
# ## 2.3 Run a test

# %%
# # Example function to run the chain
# def run_chain(input_text, schema):
#     # Run the final chain
#     final_result = chain.invoke({"schema": schema, "input_text": input_text})
#     return final_result

# %%
# import json

# # Example function to run the chain with additional exception handling
# def run_chain(input_text, schema):
#     try:
#         # Run the final chain
#         final_result = chain.invoke({"schema": schema, "input_text": input_text})
        
#         # Attempt to parse the text to extract only the JSON part
#         # Find the first '{' and last '}' to isolate JSON
#         # print(final_result)
#         start_idx = final_result.find('{')
#         end_idx = final_result.rfind('}') + 1
#         json_text = final_result[start_idx:end_idx]
#         parsed_json = json.loads(json_text)
        
#         return parsed_json
#     except (ValueError, json.JSONDecodeError) as e:
#         raise ValueError(f"Error parsing the JSON output: {e}")

# %%
# # Define a default JSON object to use in case of errors
# default_json = {
#     "target": "None",
#     "target_condition": "neutral",
#     "target_reason": "There is no significant/direct impact",
#     "influential_keywords": ["None"],
#     "price_impact": 0,
#     "price_condition": "neutral",
#     "price_reason": "There is no significant/direct impact",
#     "demand_impact": 0,
#     "demand_condition": "neutral",
#     "demand_reason": "There is no significant/direct impact",
#     "supply_impact": 0,
#     "supply_condition": "neutral",
#     "supply_reason": "There is no significant/direct impact"
# }

# Define a default JSON object to use in case of errors
default_json = {
    "target": "None",
    "target_condition": "increase",
    "influential_keywords": ["None"],
    "price_impact": 0,
    "price_condition": "increase",
    "demand_impact": 0,
    "demand_condition": "increase",
    "supply_impact": 0,
    "supply_condition": "increase"
}

# Example function to run the chain with additional exception handling
def run_chain(input_text, schema):
    try:
        # Run the final chain
        final_result = chain.invoke({"schema": schema, "input_text": input_text})
        
        # Attempt to parse the text to extract only the JSON part
        start_idx = final_result.find('{')
        end_idx = final_result.rfind('}') + 1
        json_text = final_result[start_idx:end_idx]
        parsed_json = json.loads(json_text)
        
        return parsed_json
    except (ValueError, json.JSONDecodeError) as e:
        # Log the error
        print(f"Error parsing the JSON output: {e}")
        # Return the default JSON object
        return default_json

# %%
run_chain(sample_caption, schema)
# Out:
# {'target': 'supply quantity',
#  'target_condition': 'increase',
#  'target_reason': 'There is a growing demand for battery metals, particularly lithium and copper, due to the energy transition and increasing EV production. However, processing capacity is limited, especially in the West.',
#  'influential_keywords': ['energy transition',
#   'EV battery',
#   'processing capacity',
#   'China',
#   'recycling'],
#  'price_impact': 1,
#  'price_condition': 'neutral',
#  'price_reason': "While there's increasing demand, current supply and processing capacity are balanced in the short term. Lithium prices have recently decreased, and copper prices are range-bound.",
#  'demand_impact': 2,
#  'demand_condition': 'increase',
#  'demand_reason': 'Growing demand for EVs and renewable energy technologies is driving up the need for battery metals, particularly lithium and copper.',
#  'supply_impact': 1,
#  'supply_condition': 'increase',
#  'supply_reason': "While raw material supply is sufficient, there's a need to increase processing capacity, especially in the West, to meet growing demand for battery metals."}

# %% [markdown]
# # 2. Collecting all impact scores

# %%
keyword = "LITHIUM INVESTMENT"
folder_name = "lithium investment"
dict_condition = {"increase": 1, "decrease": -1, "stable": 0, 'neutral': 0}

# Collect all the file names in the directory
file_names = os.listdir(f'jsons/{folder_name}/')

# 
dict_result = {}
dict_mean_by_date = {}

### Processing each json file
for file in tqdm(file_names):
    json_file = json.load(open(f'jsons/{folder_name}/{file}'))
    date = file.split('.')[0]
    # print(date)

    
    lst_target= []
    lst_target_condition = []
    lst_target_reason = []
    lst_influential_keywords = []
    
    lst_price_impact = []
    lst_demand_impact = []
    lst_supply_impact = []

    ### Processing each video in the json file
    for idx, video in enumerate(json_file[keyword]):
        video_caption = get_full_caption(video)
        llm = call_bedrock()

        # Check relevance
        relevance = check_relevance(llm, video_caption, keyword)
        relevance = relevance.strip("'")
        # print('actual: ', relevance)

        if relevance != 'yes':
            # print('not related')
            continue
        else:
            result = run_chain(video_caption, schema)
            # print(result)
            lst_price_impact.append(result['price_impact'] * dict_condition[result['price_condition']])
            lst_demand_impact.append(result['demand_impact'] * dict_condition[result['demand_condition']])
            lst_supply_impact.append(result['supply_impact'] * dict_condition[result['supply_condition']])
            # print(lst_price_impact)

            lst_target.append(result['target'])
            lst_target_condition.append(result['target_condition'])
            lst_influential_keywords.append(result['influential_keywords'])
        
    dict_result[date] = {
        "target": lst_target,
        "target_condition": lst_target_condition,
        "influential_keywords": lst_influential_keywords,
        "price_impact": lst_price_impact,
        "demand_impact": lst_demand_impact,
        "supply_impact": lst_supply_impact
    }
    # print(dict_result)

    try:
        dict_mean_by_date[date] = {
            "price_impact": sum(lst_price_impact) / len(lst_price_impact),
            "demand_impact": sum(lst_demand_impact) / len(lst_demand_impact),
            "supply_impact": sum(lst_supply_impact) / len(lst_supply_impact)
        }
    except:
        dict_mean_by_date[date] = {
            "price_impact": 0,
            "demand_impact": 0,
            "supply_impact": 0
        }
# Out:
#  16%|█▋        | 55/335 [1:01:44<5:08:55, 66.20s/it]
# Error parsing the JSON output: Expecting value: line 1 column 1 (char 0)
#  18%|█▊        | 61/335 [1:08:34<4:54:38, 64.52s/it]
# Error parsing the JSON output: Expecting value: line 1 column 1 (char 0)
#  19%|█▉        | 64/335 [1:13:13<5:55:57, 78.81s/it]
# Error parsing the JSON output: Expecting value: line 1 column 1 (char 0)
#  24%|██▍       | 81/335 [1:30:17<4:12:19, 59.60s/it]
# Error parsing the JSON output: Expecting value: line 1 column 1 (char 0)
#  44%|████▍     | 149/335 [2:46:32<3:53:54, 75.45s/it]
# Error parsing the JSON output: Expecting value: line 1 column 1 (char 0)
# Error parsing the JSON output: Expecting value: line 1 column 1 (char 0)
#  52%|█████▏    | 173/335 [3:13:02<3:11:35, 70.96s/it]
# Error parsing the JSON output: Expecting value: line 1 column 1 (char 0)
#  70%|███████   | 235/335 [4:20:35<1:43:02, 61.83s/it]
# Error parsing the JSON output: Expecting value: line 1 column 1 (char 0)
#  72%|███████▏  | 241/335 [4:27:20<1:52:58, 72.11s/it]
# Error parsing the JSON output: Expecting value: line 1 column 1 (char 0)
# 100%|██████████| 335/335 [6:14:05<00:00, 67.00s/it]

# %%
with open('investment_whole_output_cl3.5.json', 'w') as f:
    sorted_data = dict(sorted(dict_result.items(), key=lambda x: datetime.strptime(x[0], '%Y-%m-%d')))
    json.dump(sorted_data, f, indent=4)

with open('investment_mean_output_cl3.5.json', 'w') as f:
    sorted_data = dict(sorted(dict_mean_by_date.items(), key=lambda x: datetime.strptime(x[0], '%Y-%m-%d')))
    json.dump(sorted_data, f, indent=4)

# %%
# Feature Extarction
# entity_dict = {}
# for k in tqdm(file_list):
#     print(k)
#     score_list = []
#     reason_list = []
#     data = s3_read_json_file(bucket, k)
#     for video in tqdm(data['Ford EV']):
#         text = get_caption(video)
#         output = entity_chain.run(text[:75000])
#         try:
#             score_list.append(output['impact'] * condition_dict[output['condition']])
#         except:
#             score_list.append(0)
#         reason_list.append(output['impact reason'])
#     entity_dict[k] = {'score':score_list, 'reason':reason_list}
    
# entity_df = pd.DataFrame(entity_dict).T.reset_index()
# entity_df['date'] = entity_df['index'].apply(lambda x:x.split(".")[0].split("/")[-1])
# entity_df['year'] = entity_df['date'].apply(lambda x:int(x.split("-")[0]))
# entity_df['month'] = entity_df['date'].apply(lambda x:int(x.split("-")[1]))
# entity_df['day'] = entity_df['date'].apply(lambda x:int(x.split("-")[2]))

# %%
feature_dict = {}
for year in [2022, 2023]:
    for month in range(1, 13):
        month_df = entity_df[(entity_df['month']==month) & (entity_df['year']==year)].reset_index(drop=True)
        month_df['week'] = np.arange(month_df.shape[0])+1
        score_ = month_df['score'].values.sum()
        reason_ = month_df['reason'].values.sum()
        score = np.mean(score_)
        context = " ".join(reason_)
        reason = chain.invoke({'target':"FORD", 'context':context, 'score':score})['Impact Score Reason']
        feature_dict["{}_{}".format(year, month)] = [score, reason]

        plt.figure(figsize=(10, 3))
        plt.title("Yeaa={}, Month={}, Mean Impact Score={}, Sample={}".format(year, month, np.mean(score_), len(score_)))
        sns.distplot(score_)
        plt.show()

        plt.figure(figsize=(10, 3))
        plt.title("Change in distribution by Weekly")
        for idx, i in enumerate(month_df['score']):
            sns.distplot(i, hist=None, label="{} Week".format(idx+1))
        plt.legend()
        plt.show()

        plt.figure(figsize=(10, 3))
        plt.title("Distribution by Weekly")
        for idx, data_group in enumerate(month_df['score']):
            plt.subplot(1, len(month_df), idx + 1)
            sns.distplot(data_group)
            plt.xlim(-10, 10)
            plt.ylim(0, 0.2)
        plt.tight_layout()
        plt.show()

        print("=="*60)
    print("=="*60)
    print("=="*60)
    print("=="*60)

# %%
# def process_video_summary(self, shared_list, idx, video, key):
    
#     video_id = video['id']['videoId']
    
#     link = f'링크 : https://www.youtube.com/watch?v={video_id}\n'

#     text = " ".join([item['text'] for item in video['caption']])
#     text = text.replace("[Music]","")
#     text = text.replace("[음악]","")
#     text = text[:760000]

#     if len(text) < 10:
#         item = shared_list[idx]
#         item['summary'] = "subtitle is not available"
#         item['cod'] = "subtitle is not available"
#         item['event'] = []
#         item['news'] = []
#         shared_list[idx] = item
#         return video

#     intend = self._get_intend(text, key)

#     if 'no' in intend :
#         item = shared_list[idx]
#         item['summary'] = "Not Related to Electric Car"
#         item['cod'] = "Not Related to Electric Car"
#         item['event'] = []
#         item['news'] = []
#         shared_list[idx] = item
#         return video

#     # 본문을 Chunk 단위로 쪼갬
#     text_splitter = CharacterTextSplitter(
#         chunk_size=300000,     # 쪼개는 글자수
#         chunk_overlap=30000,   # 오버랩 글자수
#         length_function=len,
#     )

#     text = link + text
#     text = text_splitter.split_text(text)
#     docs = [Document(page_content=t) for t in text]
#     summary = self._get_summary(docs, key)
#     cod = self._get_cod(text, key)
    
#     item = shared_list[idx]
#     item['summary'] = summary
#     item['cod'] = cod
#     item['event'] = self._get_event(item)
#     item['news'] = self._get_news(item['event'], cod[-1]['Denser_Summary'], key)
#     # item['enhanced_summary'] = self._get_enhance(cod[-1]['Denser_Summary'], item['news'])
#     shared_list[idx] = item  

#     return video
